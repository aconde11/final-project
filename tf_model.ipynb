# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
# Import data
path = "clean_df.csv"

noshow_df = pd.read_csv(path)
noshow_df
# Out:
#         Age  Gender Insurance_Type Chronic_Disease Mental_Health_Status  \
# 0      93.0    Male       Medicare           False                 True
# 1      52.0    Male      Uninsured           False                False
# 2       8.0    Male       Medicare            True                  NaN
# 3       5.0   Other       Medicare           False                 True
# 4      15.0  Female       Medicaid             NaN                False
# ...     ...     ...            ...             ...                  ...
# 45037  57.0  Female        Private            True                False
# 45038  48.0  Female            NaN            True                 True
# 45039   5.0   Other       Medicaid            True                 True
# 45040  53.0    Male       Medicaid           False                False
# 45041  13.0  Female        Private           False                 True
#
#       Employment_Status  Education_Level Transportation_Access  \
# 0               Student  Advanced Degree                  True
# 1              Employed          College                  True
# 2                   NaN  Advanced Degree                  True
# 3               Student          College                  True
# 4            Unemployed      High School                  True
# ...                 ...              ...                   ...
# 45037           Student      High School                  True
# 45038           Student              NaN                  True
# 45039           Student              NaN                 False
# 45040          Employed          College                 False
# 45041           Retired              NaN                  True
#
#        Distance_from_Facility Area_Type  Days Diff Appointment_Outcome
# 0                   37.785038  Suburban        285                Show
# 1                         NaN     Rural        257             No-Show
# 2                   27.277654     Rural        622                Show
# 3                   44.618708       NaN        366                Show
# 4                   34.033755  Suburban        345                Show
# ...                       ...       ...        ...                 ...
# 45037               28.410940  Suburban         35                Show
# 45038               26.576418     Urban        113             No-Show
# 45039               20.674054  Suburban          6             No-Show
# 45040               21.190068  Suburban        231             No-Show
# 45041                     NaN  Suburban        331             No-Show
#
# [45042 rows x 12 columns]

# %%
noshow_df.dtypes
# Out:
# Age                       float64
# Gender                     object
# Insurance_Type             object
# Chronic_Disease            object
# Mental_Health_Status       object
# Employment_Status          object
# Education_Level            object
# Transportation_Access      object
# Distance_from_Facility    float64
# Area_Type                  object
# Days Diff                   int64
# Appointment_Outcome        object
# dtype: object

# %%
noshow_df.nunique()
# Out:
# Age                         101
# Gender                        3
# Insurance_Type                4
# Chronic_Disease               2
# Mental_Health_Status          2
# Employment_Status             4
# Education_Level               3
# Transportation_Access         2
# Distance_from_Facility    40494
# Area_Type                     3
# Days Diff                   724
# Appointment_Outcome           2
# dtype: int64

# %%
age_counts = noshow_df['Age'].value_counts()
age_counts
# Out:
# Age
# 28.0    452
# 94.0    443
# 96.0    441
# 2.0     440
# 9.0     438
#        ...
# 58.0    365
# 51.0    364
# 17.0    362
# 66.0    361
# 71.0    339
# Name: count, Length: 101, dtype: int64

# %%
gender_counts = noshow_df['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    13656
# Other     13501
# Male      13444
# Name: count, dtype: int64

# %%
insurance_counts = noshow_df['Insurance_Type'].value_counts()
insurance_counts
# Out:
# Insurance_Type
# Uninsured    10211
# Medicare     10163
# Private      10141
# Medicaid     10025
# Name: count, dtype: int64

# %%
chronic_disease_counts = noshow_df['Chronic_Disease'].value_counts()
chronic_disease_counts
# Out:
# Chronic_Disease
# False    20343
# True     20233
# Name: count, dtype: int64

# %%
mental_health_status_counts = noshow_df['Mental_Health_Status'].value_counts()
mental_health_status_counts
# Out:
# Mental_Health_Status
# False    20381
# True     20095
# Name: count, dtype: int64

# %%
employment_status_counts = noshow_df['Employment_Status'].value_counts()
employment_status_counts
# Out:
# Employment_Status
# Employed      10192
# Retired       10118
# Student       10089
# Unemployed    10031
# Name: count, dtype: int64

# %%
education_level_counts = noshow_df['Education_Level'].value_counts()
education_level_counts

# Missing 'None' values
# Out:
# Education_Level
# High School        10277
# Advanced Degree    10261
# College             9872
# Name: count, dtype: int64

# %%
transportation_access_counts = noshow_df['Transportation_Access'].value_counts()
transportation_access_counts
# Out:
# Transportation_Access
# False    20308
# True     20212
# Name: count, dtype: int64

# %%
distance_counts = noshow_df['Distance_from_Facility'].value_counts()
distance_counts
# Out:
# Distance_from_Facility
# 37.785038    1
# 7.728993     1
# 39.040855    1
# 44.856200    1
# 44.440638    1
#             ..
# 39.135709    1
# 12.547019    1
# 21.085779    1
# 13.770227    1
# 21.190068    1
# Name: count, Length: 40494, dtype: int64

# %%
area_counts = noshow_df['Area_Type'].value_counts()
area_counts
# Out:
# Area_Type
# Urban       13586
# Rural       13505
# Suburban    13475
# Name: count, dtype: int64

# %%
days_diff_counts = noshow_df['Days Diff'].value_counts()
days_diff_counts
# Out:
# Days Diff
# 307    113
# 123    110
# 106    108
# 101    106
# 217    105
#       ...
# 714      1
# 723      1
# 727      1
# 710      1
# 713      1
# Name: count, Length: 724, dtype: int64

# %%
appt_outcome_counts = noshow_df['Appointment_Outcome'].value_counts()
appt_outcome_counts
# Out:
# Appointment_Outcome
# Show       22575
# No-Show    22467
# Name: count, dtype: int64

# %%
# Map Appointment Outcome column to 0's and 1's
noshow_df['Appointment_Outcome'] = noshow_df['Appointment_Outcome'].map({'Show':1, 'No-Show':0})

# %%
# Convert categorical data to numeric with `pd.get_dummies`
noshow_df_dummies = pd.get_dummies(noshow_df)
noshow_df_dummies.dtypes
# Out:
# Age                                float64
# Distance_from_Facility             float64
# Days Diff                            int64
# Appointment_Outcome                  int64
# Gender_Female                         bool
# Gender_Male                           bool
# Gender_Other                          bool
# Insurance_Type_Medicaid               bool
# Insurance_Type_Medicare               bool
# Insurance_Type_Private                bool
# Insurance_Type_Uninsured              bool
# Chronic_Disease_False                 bool
# Chronic_Disease_True                  bool
# Mental_Health_Status_False            bool
# Mental_Health_Status_True             bool
# Employment_Status_Employed            bool
# Employment_Status_Retired             bool
# Employment_Status_Student             bool
# Employment_Status_Unemployed          bool
# Education_Level_Advanced Degree       bool
# Education_Level_College               bool
# Education_Level_High School           bool
# Transportation_Access_False           bool
# Transportation_Access_True            bool
# Area_Type_Rural                       bool
# Area_Type_Suburban                    bool
# Area_Type_Urban                       bool
# dtype: object

# %%
noshow_df_dummies
# Out:
#         Age  Distance_from_Facility  Days Diff  Appointment_Outcome  \
# 0      93.0               37.785038        285                    1
# 1      52.0                     NaN        257                    0
# 2       8.0               27.277654        622                    1
# 3       5.0               44.618708        366                    1
# 4      15.0               34.033755        345                    1
# ...     ...                     ...        ...                  ...
# 45037  57.0               28.410940         35                    1
# 45038  48.0               26.576418        113                    0
# 45039   5.0               20.674054          6                    0
# 45040  53.0               21.190068        231                    0
# 45041  13.0                     NaN        331                    0
#
#        Gender_Female  Gender_Male  Gender_Other  Insurance_Type_Medicaid  \
# 0              False         True         False                    False
# 1              False         True         False                    False
# 2              False         True         False                    False
# 3              False        False          True                    False
# 4               True        False         False                     True
# ...              ...          ...           ...                      ...
# 45037           True        False         False                    False
# 45038           True        False         False                    False
# 45039          False        False          True                     True
# 45040          False         True         False                     True
# 45041           True        False         False                    False
#
#        Insurance_Type_Medicare  Insurance_Type_Private  ...  \
# 0                         True                   False  ...
# 1                        False                   False  ...
# 2                         True                   False  ...
# 3                         True                   False  ...
# 4                        False                   False  ...
# ...                        ...                     ...  ...
# 45037                    False                    True  ...
# 45038                    False                   False  ...
# 45039                    False                   False  ...
# 45040                    False                   False  ...
# 45041                    False                    True  ...
#
#        Employment_Status_Student  Employment_Status_Unemployed  \
# 0                           True                         False
# 1                          False                         False
# 2                          False                         False
# 3                           True                         False
# 4                          False                          True
# ...                          ...                           ...
# 45037                       True                         False
# 45038                       True                         False
# 45039                       True                         False
# 45040                      False                         False
# 45041                      False                         False
#
#        Education_Level_Advanced Degree  Education_Level_College  \
# 0                                 True                    False
# 1                                False                     True
# 2                                 True                    False
# 3                                False                     True
# 4                                False                    False
# ...                                ...                      ...
# 45037                            False                    False
# 45038                            False                    False
# 45039                            False                    False
# 45040                            False                     True
# 45041                            False                    False
#
#        Education_Level_High School  Transportation_Access_False  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                             True                        False
# ...                            ...                          ...
# 45037                         True                        False
# 45038                        False                        False
# 45039                        False                         True
# 45040                        False                         True
# 45041                        False                        False
#
#        Transportation_Access_True  Area_Type_Rural  Area_Type_Suburban  \
# 0                            True            False                True
# 1                            True             True               False
# 2                            True             True               False
# 3                            True            False               False
# 4                            True            False                True
# ...                           ...              ...                 ...
# 45037                        True            False                True
# 45038                        True            False               False
# 45039                       False            False                True
# 45040                       False            False                True
# 45041                        True            False                True
#
#        Area_Type_Urban
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 45037            False
# 45038             True
# 45039            False
# 45040            False
# 45041            False
#
# [45042 rows x 27 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = noshow_df_dummies.drop('Appointment_Outcome', axis=1)
y = noshow_df_dummies['Appointment_Outcome']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
len(X_train_scaled[0])
# Out:
# 26

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 216
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 267
# Trainable params: 267
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1127/1127 [==============================] - 2s 934us/step - loss: 0.6932 - accuracy: 0.4975
# Epoch 2/100
# 1127/1127 [==============================] - 1s 940us/step - loss: 0.6932 - accuracy: 0.4985
# Epoch 3/100
# 1127/1127 [==============================] - 1s 981us/step - loss: 0.6932 - accuracy: 0.4998
# Epoch 4/100
# 1127/1127 [==============================] - 1s 952us/step - loss: 0.6932 - accuracy: 0.4961
# Epoch 5/100
# 1127/1127 [==============================] - 1s 990us/step - loss: 0.6932 - accuracy: 0.4957
# Epoch 6/100
# 1127/1127 [==============================] - 1s 990us/step - loss: 0.6932 - accuracy: 0.5025
# Epoch 7/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4975
# Epoch 8/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4969
# Epoch 9/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4990
# Epoch 10/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 11/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 12/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4952
# Epoch 13/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4972
# Epoch 14/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4960
# Epoch 15/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4986
# Epoch 16/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4965
# Epoch 17/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5027
# Epoch 18/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 19/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4948
# Epoch 20/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4959
# Epoch 21/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4993
# Epoch 22/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4969
# Epoch 23/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 24/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4998
# Epoch 25/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4972
# Epoch 26/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4977
# Epoch 27/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4935
# Epoch 28/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4972
# Epoch 29/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5011
# Epoch 30/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4946
# Epoch 31/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4978
# Epoch 32/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5008
# Epoch 33/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4973
# Epoch 34/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4992
# Epoch 35/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4986
# Epoch 36/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 37/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4935
# Epoch 38/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4980
# Epoch 39/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4989
# Epoch 40/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4969
# Epoch 41/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4977
# Epoch 42/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4990
# Epoch 43/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5015
# Epoch 44/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4995
# Epoch 45/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4944
# Epoch 46/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4950
# Epoch 47/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 48/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4959
# Epoch 49/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4981
# Epoch 50/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4978
# Epoch 51/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4979
# Epoch 52/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4986
# Epoch 53/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4994
# Epoch 54/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4963
# Epoch 55/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 56/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 57/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4987
# Epoch 58/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5018
# Epoch 59/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.5005
# Epoch 60/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4978
# Epoch 61/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4999
# Epoch 62/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4988
# Epoch 63/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4959
# Epoch 64/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4990
# Epoch 65/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4988
# Epoch 66/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4980
# Epoch 67/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4997
# Epoch 68/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 69/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4977
# Epoch 70/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4992
# Epoch 71/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4978
# Epoch 72/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4993
# Epoch 73/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 74/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4944
# Epoch 75/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4994
# Epoch 76/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 77/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4926
# Epoch 78/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4987
# Epoch 79/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4972
# Epoch 80/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4945
# Epoch 81/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 82/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4992
# Epoch 83/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5003
# Epoch 84/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4990
# Epoch 85/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4964
# Epoch 86/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4981
# Epoch 87/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4991
# Epoch 88/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 89/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.5010
# Epoch 90/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4970
# Epoch 91/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4998
# Epoch 92/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4975
# Epoch 93/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4948
# Epoch 94/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4999
# Epoch 95/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4974
# Epoch 96/100
# 1127/1127 [==============================] - 2s 1ms/step - loss: 0.6932 - accuracy: 0.4994
# Epoch 97/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4977
# Epoch 98/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4987
# Epoch 99/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4994
# Epoch 100/100
# 1127/1127 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.4980

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 282/282 - 0s - loss: 0.6931 - accuracy: 0.5052 - 475ms/epoch - 2ms/step
# Loss: 0.6931353211402893, Accuracy: 0.5051615238189697
